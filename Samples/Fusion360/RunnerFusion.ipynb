# %%
# Empire AI Automation Setup
# Version: 0.1
#
# Copy and paste this as 1st cell into Your workbook to start making automation notebook
# Use the #Factory# page to create new steps
# More videos and tutorials @link
# by Kaspar Kallas 2023 (kaspar.kana.kallas@gmail.com)

try:
    test = time.time()
except:
    import pyperclip
    import platform
    import time
    import pyautogui as gui
    import io
    import cv2
    import numpy as np
    import codecs
    import dill
    import pandas as pd
    import pyarrow.feather as feather
    from ipywidgets import widgets, Image, Output

class step:
    """
    Empire AI step protocol 0.1
    Inputs step('''xxx''', tries=3, timer=1, gate=1, bbox=None)
    Output step.locations (tuples of x,y in screen space)
    
    """
    def __init__(self, payload, tries=3, timer=1, gate=1, bbox=None, kill_on_fail=True):
        self.payloads = dill.loads(codecs.decode(payload.encode(), "base64"))
        self.pattern_img = self.payloads[0]
        self.offset = self.payloads[1]
        self.kill_on_fail = kill_on_fail
        self.version = 0.1
        
        # Try to find the pattern
        for counter in range(tries):
            self._find_()
            # If enough instances have been found break out of the loop and execute next cell
            if len(self.locations) >= gate:
                print("found: "+str(self.locations))
                break
            else:
                time.sleep(timer)
        
        # If the pattern is not found within timeout
        if len(self.locations) < gate:
            pr.style={'bar_color': '#800000'}
            pl.value="[STOPPED] could not find"
            print("EXCEPTION: Gate condition not met!")
            if kill_on_fail:
                pr.style={'bar_color': '#808000'}
                raise Exception("Gate condition not met!")
        
    def _find_(self):
        """
        Find pattern on the screen as many instances as possible
        save all found locations into self.locations with correct click offset
        """
        
        self.locations = []
        locations_found = gui.locateAllOnScreen(self.pattern_img)
        offset = self.payloads[1]
        
        for loc in locations_found:
            self.locations.append((loc.left+offset[0],loc.top+offset[1]))
            
def os_ctrl(short=False):
    """
    Control buton string replacement to be used with pyautogui lib
    in win/linux it is ctrl and osx cmd/command
    """
    if platform.system() == 'Darwin':
        if short:
            return 'cmd'
        else:
            return 'command'
    else:
        return 'ctrl'

# %%
# Right click and select "Create New View for Output" the You get progress bar always visible 
pr = widgets.IntProgress(min=0,max=100,layout=widgets.Layout(width='90%'), description="progress 100% ")
px = widgets.IntProgress(min=0,max=100,layout=widgets.Layout(width='90%'), description="total 11/11 ")
pl = widgets.Label(description="debug")
widgets.VBox([px,pr,pl])
# Out:
# VBox(children=(IntProgress(value=0, description='total 11/11 ', layout=Layout(width='90%')), IntProgress(value…

# %% [markdown]
# make sure that none of the files are selected in the "sidebar"

# %% [markdown]
# find all "exportable" files
#
# ![image.png](attachment:b717971a-c533-4e02-ae04-914d28583281.png)

# %%
# Empire AI Automation Step Setup
s = step(
    '''...''',
    tries=3,
    timer=1,
    gate=1,
    bbox=None
)
# Logic here
# trim locations if necessary
loc = s.locations
loclen = len(loc)

px.value = 0
px.max = loclen
px.description = "total 0/"+str(loclen)
pl.value="[started]"


for i in loc:
    px.description = "total "+str(current_pass+1)+"/"+str(loclen)
    px.value = current_pass+1
    gui.doubleClick(i[0],i[1])
    time.sleep(0.4)

    try:
        # %run ./Fusion360_single_export.ipynb
    except:
        pass
# Out:
# found: [(81, 362), (81, 482), (81, 602), (81, 722), (81, 842), (81, 962), (81, 1082), (81, 1202)]
# found: [(676, 70)]
# found: [(697, 445)]
# found: [(1498, 856)]
# found: [(1151, 72)]
# found: [(676, 70)]
# EXCEPTION: Gate condition not met!
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_59580\822660508.py:2
#       1 # Empire AI Automation Step Setup
# ----> 2 s = step(
#       3     '''...''',
#       4     tries=3,
#       5     timer=1,
#       6     gate=1,
#       7     bbox=None
#       8 )
#       9 # Logic here
#      10 for i in s.locations:
#
# File ~\AppData\Local\Temp\ipykernel_59580\2056140907.py:56, in step.__init__(self, payload, tries, timer, gate, bbox, kill_on_fail)
#      54 if kill_on_fail:
#      55     pr.style={'bar_color': '#808000'}
# ---> 56     raise Exception("Gate condition not met!")
#
# Exception: Gate condition not met!
# found: [(676, 70)]
# found: [(697, 445)]
# found: [(1498, 856)]
# found: [(1661, 72)]
# found: [(676, 70)]
# found: [(697, 445)]
# found: [(1498, 856)]
# found: [(1661, 72)]
# found: [(676, 70)]
# found: [(697, 445)]
# found: [(1498, 856)]
# found: [(1661, 72)]
# found: [(676, 70)]
# found: [(697, 445)]
# found: [(1498, 856)]
# found: [(1661, 72)]
# found: [(676, 70)]
# found: [(697, 445)]
# found: [(1498, 856)]
# found: [(1661, 72)]
# found: [(676, 70)]
# found: [(697, 445)]
# found: [(1498, 856)]
# found: [(1661, 72)]

# %%
px.value = 0
px.max = 40
px.description = "total 0/40 "
sucess = 0
pl.value="[started]"

for current_pass in range(40):
    px.description = "total "+str(current_pass+1)+"/40 "
    px.value = current_pass+1
    try:
        # %run Instagram_collect.ipynb
        sucess = sucess+1
    except:
        # How to create a break?
        pass
    print("current out: "+str(line))
    worklist.loc[len(worklist.index)] = line
    
pl.value="Sucsfull "+str(sucess)+" ie "+str(sucess/5*100)+"%"
# Out:
# found: [(1991, 638)]
# found: [(984, 932)]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_59580\3105193541.py:20
#      18     txt = pyperclip.paste()
#      19     count = [int(s) for s in txt.split() if s.isdigit()]
# ---> 20     print("the post has "+str(count[0])+"/"+str(max_likes)+" likes")
#      23 likes = count[0]
#      24 if likes>max_likes:
#
# IndexError: list index out of range
# current out: ['https://www.instagram.com/p/CZuOWDxq4Ju/', 960, False]
# found: [(1991, 637)]
# found: [(984, 932)]
# the post has 713/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CZMjV7Tq6Cs/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CZMjV7Tq6Cs/', 713, False]
# found: [(1991, 637)]
# found: [(890, 932)]
# the post has 39/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CY_qtunh0eD/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CY_qtunh0eD/', 39, False]
# found: [(1991, 638)]
# found: [(984, 932)]
# the post has 164/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CY9K4qEo2FU/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CY9K4qEo2FU/', 164, False]
# found: [(1991, 638)]
# found: [(984, 932)]
# the post has 127/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CY6gvmJq4NJ/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CY6gvmJq4NJ/', 127, False]
# found: [(1991, 637)]
# found: [(984, 932)]
# the post has 342/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CY1YQZxq4YK/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CY1YQZxq4YK/', 342, False]
# found: [(1991, 637)]
# found: [(890, 932)]
# the post has 39/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CYjY7Kmho5G/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CYjY7Kmho5G/', 39, False]
# found: [(1991, 638)]
# found: [(1063, 932)]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_59580\3105193541.py:20
#      18     txt = pyperclip.paste()
#      19     count = [int(s) for s in txt.split() if s.isdigit()]
# ---> 20     print("the post has "+str(count[0])+"/"+str(max_likes)+" likes")
#      23 likes = count[0]
#      24 if likes>max_likes:
#
# IndexError: list index out of range
# current out: ['https://www.instagram.com/p/CYjY7Kmho5G/', 39, False]
# found: [(1991, 638)]
# found: [(984, 932)]
# the post has 89/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CYWga12oago/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CYWga12oago/', 89, False]
# found: [(1991, 637)]
# found: [(984, 932)]
# the post has 365/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CYT6Ui8IdyN/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CYT6Ui8IdyN/', 365, False]
# found: [(1991, 637)]
# found: [(1063, 932)]
# the post has 337/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CYJuDkwIgma/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CYJuDkwIgma/', 337, False]
# found: [(1991, 638)]
# found: [(984, 932)]
# the post has 478/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CX_ULG3otLG/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CX_ULG3otLG/', 478, False]
# found: [(1991, 637)]
# found: [(984, 932)]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_59580\3105193541.py:20
#      18     txt = pyperclip.paste()
#      19     count = [int(s) for s in txt.split() if s.isdigit()]
# ---> 20     print("the post has "+str(count[0])+"/"+str(max_likes)+" likes")
#      23 likes = count[0]
#      24 if likes>max_likes:
#
# IndexError: list index out of range
# current out: ['https://www.instagram.com/p/CX_ULG3otLG/', 478, False]
# found: [(1991, 637)]
# found: [(1063, 932)]
# the post has 95/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CXyWYt-o6g6/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CXyWYt-o6g6/', 95, False]
# found: [(1991, 638)]
# found: [(984, 932)]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_59580\3105193541.py:20
#      18     txt = pyperclip.paste()
#      19     count = [int(s) for s in txt.split() if s.isdigit()]
# ---> 20     print("the post has "+str(count[0])+"/"+str(max_likes)+" likes")
#      23 likes = count[0]
#      24 if likes>max_likes:
#
# IndexError: list index out of range
# current out: ['https://www.instagram.com/p/CXyWYt-o6g6/', 95, False]
# found: [(1991, 637)]
# found: [(1063, 932)]
# the post has 54/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CXi1uTmoIWN/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CXi1uTmoIWN/', 54, False]
# found: [(1991, 638)]
# found: [(1063, 932)]
# the post has 191/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CXgpnKoL5R7/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CXgpnKoL5R7/', 191, False]
# found: [(1991, 638)]
# found: [(890, 932)]
# the post has 37/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CXf4iTSA0L-/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CXf4iTSA0L-/', 37, False]
# found: [(1991, 638)]
# found: [(984, 932)]
# the post has 114/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CXfrrrFINPp/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CXfrrrFINPp/', 114, False]
# found: [(1991, 637)]
# found: [(1063, 932)]
# the post has 44/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CXdmE0Qob_p/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CXdmE0Qob_p/', 44, False]
# found: [(1991, 638)]
# found: [(984, 932)]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_59580\3105193541.py:20
#      18     txt = pyperclip.paste()
#      19     count = [int(s) for s in txt.split() if s.isdigit()]
# ---> 20     print("the post has "+str(count[0])+"/"+str(max_likes)+" likes")
#      23 likes = count[0]
#      24 if likes>max_likes:
#
# IndexError: list index out of range
# current out: ['https://www.instagram.com/p/CXdmE0Qob_p/', 44, False]
# found: [(1991, 637)]
# found: [(984, 932)]
# the post has 684/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CXObKNIo8Kk/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CXObKNIo8Kk/', 684, False]
# found: [(1991, 638)]
# found: [(984, 932)]
# the post has 820/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CXLOnz0LVri/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CXLOnz0LVri/', 820, False]
# found: [(1991, 637)]
# found: [(890, 932)]
# the post has 74/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CW-z_DMou3S/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CW-z_DMou3S/', 74, False]
# found: [(1991, 638)]
# found: [(984, 923)]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_59580\3105193541.py:20
#      18     txt = pyperclip.paste()
#      19     count = [int(s) for s in txt.split() if s.isdigit()]
# ---> 20     print("the post has "+str(count[0])+"/"+str(max_likes)+" likes")
#      23 likes = count[0]
#      24 if likes>max_likes:
#
# IndexError: list index out of range
# current out: ['https://www.instagram.com/p/CW-z_DMou3S/', 74, False]
# found: [(1991, 637)]
# found: [(984, 932)]
# the post has 264/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CW70VNcLG0j/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CW70VNcLG0j/', 264, False]
# found: [(1991, 637)]
# found: [(1063, 932)]
# the post has 421/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CW6KyCnogAF/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CW6KyCnogAF/', 421, False]
# found: [(1991, 638)]
# found: [(984, 932)]
# the post has 193/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CW5UUfQIp_y/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CW5UUfQIp_y/', 193, False]
# found: [(1991, 637)]
# found: [(984, 923)]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_59580\3105193541.py:20
#      18     txt = pyperclip.paste()
#      19     count = [int(s) for s in txt.split() if s.isdigit()]
# ---> 20     print("the post has "+str(count[0])+"/"+str(max_likes)+" likes")
#      23 likes = count[0]
#      24 if likes>max_likes:
#
# IndexError: list index out of range
# current out: ['https://www.instagram.com/p/CW5UUfQIp_y/', 193, False]
# found: [(1991, 637)]
# found: [(984, 932)]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_59580\3105193541.py:20
#      18     txt = pyperclip.paste()
#      19     count = [int(s) for s in txt.split() if s.isdigit()]
# ---> 20     print("the post has "+str(count[0])+"/"+str(max_likes)+" likes")
#      23 likes = count[0]
#      24 if likes>max_likes:
#
# IndexError: list index out of range
# current out: ['https://www.instagram.com/p/CW5UUfQIp_y/', 193, False]
# found: [(1991, 637)]
# found: [(890, 932)]
# the post has 89/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CW2vdPNokG3/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CW2vdPNokG3/', 89, False]
# found: [(1991, 638)]
# found: [(1063, 932)]
# the post has 77/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CWs8cz4qsb1/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CWs8cz4qsb1/', 77, False]
# found: [(1991, 638)]
# found: [(984, 932)]
# the post has 519/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CWsTEWQKGb3/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CWsTEWQKGb3/', 519, False]
# found: [(1991, 637)]
# found: [(890, 932)]
# the post has 84/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CWqr54zI8hq/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CWqr54zI8hq/', 84, False]
# found: [(1991, 638)]
# found: [(984, 932)]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_59580\3105193541.py:20
#      18     txt = pyperclip.paste()
#      19     count = [int(s) for s in txt.split() if s.isdigit()]
# ---> 20     print("the post has "+str(count[0])+"/"+str(max_likes)+" likes")
#      23 likes = count[0]
#      24 if likes>max_likes:
#
# IndexError: list index out of range
# current out: ['https://www.instagram.com/p/CWqr54zI8hq/', 84, False]
# found: [(1991, 637)]
# found: [(1063, 932)]
# the post has 158/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CWlC40fKmOy/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CWlC40fKmOy/', 158, False]
# found: [(1991, 638)]
# found: [(984, 932)]
# the post has 805/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CWbUGorovVT/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CWbUGorovVT/', 805, False]
# found: [(1991, 637)]
# found: [(1063, 932)]
# the post has 39/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CWVzOqrI-We/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CWVzOqrI-We/', 39, False]
# found: [(1991, 638)]
# found: [(984, 932)]
# the post has 142/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CWTre4cLG9K/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CWTre4cLG9K/', 142, False]
# found: [(1991, 637)]
# found: [(984, 932)]
# the post has 130/20 likes
# found: [(261, 97), (250, 1213)]
# https://www.instagram.com/p/CWLhdGCqQJR/
# EXCEPTION: Gate condition not met!
# current out: ['https://www.instagram.com/p/CWLhdGCqQJR/', 130, False]

# %%
worklist
# Out:
#                                       web url  likes  have I liked
# 0    https://www.instagram.com/p/Cjs4SjiDZZg/    108         False
# 1    https://www.instagram.com/p/CjifMnDoS_e/     92         False
# 2    https://www.instagram.com/p/CjTA6QOo5Zo/     37         False
# 3    https://www.instagram.com/p/Ci-f-BFIJWi/    559         False
# 4    https://www.instagram.com/p/Ci2qQPvI_Hl/    237         False
# ..                                        ...    ...           ...
# 120  https://www.instagram.com/p/CWlC40fKmOy/    158         False
# 121  https://www.instagram.com/p/CWbUGorovVT/    805         False
# 122  https://www.instagram.com/p/CWVzOqrI-We/     39         False
# 123  https://www.instagram.com/p/CWTre4cLG9K/    142         False
# 124  https://www.instagram.com/p/CWLhdGCqQJR/    130         False
#
# [125 rows x 3 columns]

# %%
feather.write_feather(worklist,'.\worklist.feather')

# %%
xx=feather.read_feather('worklist.feather')

# %%
outlist = worklist.drop_duplicates('web url', ignore_index=True)

# %%
outlist.query("likes < 50 and likes > 30")
# Out:
#                                      web url  likes  have I liked
# 2   https://www.instagram.com/p/CjTA6QOo5Zo/     37         False
# 8   https://www.instagram.com/p/ChSUoXUIFks/     38         False
# 14  https://www.instagram.com/p/CeljP4KOzQZ/     35         False
# 17  https://www.instagram.com/p/CdqanDGoQug/     44         False
# 19  https://www.instagram.com/p/CdYegxZIqma/     44         False
# 21  https://www.instagram.com/p/CdJGXfNoC8L/     38         False
# 30  https://www.instagram.com/p/Ca2hUansFfQ/     41         False
# 44  https://www.instagram.com/p/CY_qtunh0eD/     39         False
# 48  https://www.instagram.com/p/CYjY7Kmho5G/     39         False
# 56  https://www.instagram.com/p/CXf4iTSA0L-/     37         False
# 58  https://www.instagram.com/p/CXdmE0Qob_p/     44         False
# 71  https://www.instagram.com/p/CWVzOqrI-We/     39         False

# %%
import random

def genseed(inp):
    if random.randrange(0,10)>8:
        return False
    else:
        return True
    
outlist['edit'] = outlist['web url'].apply(genseed)
# Out:
# C:\Users\Virtual Production 2\AppData\Local\Temp\ipykernel_59580\3243329274.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
outlist # .drop(columns=['edit'])
# Out:
#                                      web url  likes  have I liked   edit
# 0   https://www.instagram.com/p/Cjs4SjiDZZg/    108         False   True
# 1   https://www.instagram.com/p/CjifMnDoS_e/     92         False   True
# 2   https://www.instagram.com/p/CjTA6QOo5Zo/     37         False   True
# 3   https://www.instagram.com/p/Ci-f-BFIJWi/    559         False  False
# 4   https://www.instagram.com/p/Ci2qQPvI_Hl/    237         False   True
# ..                                       ...    ...           ...    ...
# 69  https://www.instagram.com/p/CWlC40fKmOy/    158         False   True
# 70  https://www.instagram.com/p/CWbUGorovVT/    805         False   True
# 71  https://www.instagram.com/p/CWVzOqrI-We/     39         False  False
# 72  https://www.instagram.com/p/CWTre4cLG9K/    142         False   True
# 73  https://www.instagram.com/p/CWLhdGCqQJR/    130         False   True
#
# [74 rows x 4 columns]

# %%
finallist = outlist.query("edit == True and likes < 50")

# %%
list(finallist.loc[:,'web url'])
# Out:
# ['https://www.instagram.com/p/CjTA6QOo5Zo/',
#  'https://www.instagram.com/p/ChSUoXUIFks/',
#  'https://www.instagram.com/p/CdqanDGoQug/',
#  'https://www.instagram.com/p/CdYegxZIqma/',
#  'https://www.instagram.com/p/CdJGXfNoC8L/',
#  'https://www.instagram.com/p/Ca2hUansFfQ/',
#  'https://www.instagram.com/p/CaXZl7sJJ46/',
#  'https://www.instagram.com/p/CY_qtunh0eD/',
#  'https://www.instagram.com/p/CYjY7Kmho5G/',
#  'https://www.instagram.com/p/CXf4iTSA0L-/',
#  'https://www.instagram.com/p/CXdmE0Qob_p/']
