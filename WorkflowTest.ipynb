# %% [markdown]
# ## Genrate Stock Product Label(s) for Odoo Inventory Adjustments
#
# Script will take a string from Odoo page copied to print n numebr of labels with direct links as QR codes for LOT, product_id, lot_id
# The printing base layout is Draw.io preoject, fill in the images and data
#
# Start Layout:
# ![image.png](attachment:c531b3af-8d90-408b-88bd-d6320d92c488.png)

# %% [markdown]
# #### Automated

# %%
skip_step = False # Used to skip next step, reset every time used
handbreak = False # When activated then the rest of the workbook is not exectued

# %% [markdown]
# ### Open Odoo Lots
# This step will find DS Odoo Chrome window and click on the adress bar to activate the window
# ![image.png](attachment:ae726918-1df9-4d77-920d-9c48287f0ec0.png)

# %% [markdown]
# #### Automated

# %%
# Activate Odoo
# Pre-Script
def pre_script():
    print("Starting step...")
# Post-Script
def main_script():
    if len(locations)>0:
        print("found "+str(len(locations))+" locations")
        # UI debounce (opening window time not to click too quick, make it longer if ncessary)
        # Use next step as timeout waiting for progress
        time.sleep(0.01)

        # MOUSE
        gui.moveTo(locations[0][1])
        print(locations[0][1])
        #gui.click(abs_location[0], abs_location[1])
        #gui.click(abs_location[0], abs_location[1], button='right')
        #gui.click(abs_location[0], abs_location[1], clicks=2)

        #exec("out1="+text.value,globals())
        #current_txt = out1       
        #pyperclip.copy(out1)
        #gui.hotkey(os_ctrl(),'v')

        #gui.hotkey(os_ctrl(),'a')
        #gui.press('enter')

    else:
        print("no locations found")

# %%
import dill
import codecs
import time
import pyautogui as gui
payload = '''
'''

# Calling the script by name to make the editing easier
try:
    pre_script()
except:
    print ("[!] no pre_script")

pre_script = None
pattern_img = dill.loads(codecs.decode(payload.encode(), "base64"))
print("Findig pattern...")
locations = []
locations_found = gui.locateAllOnScreen(pattern_img)
for i in locations_found:
    print(i)
    locations.append((i,(i[0]+335,i[1]+78)))
# TODO Create display to show all found areas with outlines
try:
    main_script()
except:
    print ("[!] no main_script")

pre_script = None
main_script = None
# Out:
# [!] no pre_script
# Findig pattern...
# Box(left=1, top=6, width=58, height=71)
# found 1 locations
# (336, 84)

# %%
main_script == None
# Out:
# True

# %% [markdown]
# ### Clean Odoo Lots Search bar
# This step will find DS Odoo Search Bar and click on the cross of any filter or grouping untill none are left

# %% [markdown]
# ### Add text to Odoo Lots Search bar
# This step will find DS Odoo Search Bar and click above the line to enter 'product_id', 'lot_id'

# %% [markdown]
# ### Open Odoo Lot by clicking the topmost hit
# This step will find Lots/Serial Numbers page header and click on the 1st line

# %% [markdown]
# ### Payload
#  - [ ] Skipping mechanism
#  - [ ] Stepping back or subfunction? (%run)

# %%
my_test_var = "my super secret string"
